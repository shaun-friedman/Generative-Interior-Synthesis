# %%
# %pip install -r ./src/requirements.txt
# Out:
# Requirement already satisfied: absl-py==2.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: accelerate==1.13.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 2)) (1.13.0)
# Requirement already satisfied: adagio==0.2.6 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 3)) (0.2.6)
# Requirement already satisfied: aioboto3==14.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 4)) (14.3.0)
# Requirement already satisfied: aiobotocore==2.22.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 5)) (2.22.0)
# Requirement already satisfied: aiofiles==25.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 6)) (25.1.0)
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: aiohttp==3.13.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 8)) (3.13.3)
# Requirement already satisfied: aiohttp-cors==0.8.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 9)) (0.8.1)
# Requirement already satisfied: aioitertools==0.13.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 10)) (0.13.0)
# Requirement already satisfied: aiosignal==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: aiosqlite==0.19.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 12)) (0.19.0)
# Requirement already satisfied: alembic==1.18.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 13)) (1.18.4)
# Requirement already satisfied: altair==5.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 14)) (5.5.0)
# Requirement already satisfied: amazon-q-developer-jupyterlab-ext==3.4.8 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 15)) (3.4.8)
# Requirement already satisfied: amazon_sagemaker_jupyter_ai_q_developer==1.2.9 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 16)) (1.2.9)
# Requirement already satisfied: amazon_sagemaker_jupyter_scheduler==3.1.16 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 17)) (3.1.16)
# Requirement already satisfied: amazon-sagemaker-sql-editor==0.1.21 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 18)) (0.1.21)
# Requirement already satisfied: amazon-sagemaker-sql-execution==0.1.9 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 19)) (0.1.9)
# Requirement already satisfied: amazon-sagemaker-sql-magic==0.1.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 20)) (0.1.4)
# Requirement already satisfied: amzn_sagemaker_aiops_jupyterlab_extension==1.0.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 21)) (1.0.5)
# Requirement already satisfied: annotated-doc==0.0.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 22)) (0.0.4)
# Requirement already satisfied: annotated-types==0.7.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 23)) (0.7.0)
# Requirement already satisfied: ansi2html==1.9.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 24)) (1.9.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 25)) (4.9.3)
# Requirement already satisfied: anyio==4.12.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 26)) (4.12.1)
# Requirement already satisfied: apsw==3.48.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 27)) (3.48.0.0)
# Requirement already satisfied: apswutils==0.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 28)) (0.1.2)
# Requirement already satisfied: archspec==0.2.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 29)) (0.2.5)
# Requirement already satisfied: argon2-cffi==25.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 30)) (25.1.0)
# Requirement already satisfied: argon2-cffi-bindings==25.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 31)) (25.1.0)
# Requirement already satisfied: arro3-core==0.8.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 32)) (0.8.0)
# Requirement already satisfied: arrow==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 33)) (1.4.0)
# Requirement already satisfied: asn1crypto==1.5.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 34)) (1.5.1)
# Requirement already satisfied: astroid==4.0.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 35)) (4.0.4)
# Requirement already satisfied: asttokens==3.0.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 36)) (3.0.1)
# Requirement already satisfied: astunparse==1.6.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 37)) (1.6.3)
# Requirement already satisfied: async-lru==2.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 38)) (2.2.0)
# Requirement already satisfied: async-timeout==4.0.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 39)) (4.0.3)
# Requirement already satisfied: attrs==23.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 40)) (23.2.0)
# Requirement already satisfied: autogluon==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 41)) (1.5.0)
# Requirement already satisfied: autogluon.common==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 42)) (1.5.0)
# Requirement already satisfied: autogluon.core==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 43)) (1.5.0)
# Requirement already satisfied: autogluon.features==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 44)) (1.5.0)
# Requirement already satisfied: autogluon.multimodal==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 45)) (1.5.0)
# Requirement already satisfied: autogluon.tabular==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 46)) (1.5.0)
# Requirement already satisfied: autogluon.timeseries==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 47)) (1.5.0)
# Requirement already satisfied: autopep8==2.0.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 48)) (2.0.4)
# Requirement already satisfied: autovizwidget==0.23.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 49)) (0.23.0)
# Requirement already satisfied: aws-embedded-metrics==3.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 50)) (3.3.0)
# Requirement already satisfied: aws-glue-sessions==1.0.9 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 51)) (1.0.9)
# Requirement already satisfied: aws-requests-auth==0.4.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 52)) (0.4.3)
# Requirement already satisfied: aws_s3_access_grants_boto3_plugin==1.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 53)) (1.2.0)
# Requirement already satisfied: awswrangler==3.15.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 54)) (3.15.1)
# Requirement already satisfied: babel==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 55)) (2.18.0)
# Requirement already satisfied: bcrypt==5.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 56)) (5.0.0)
# Requirement already satisfied: beartype==0.22.9 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 57)) (0.22.9)
# Requirement already satisfied: beautifulsoup4==4.14.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 58)) (4.14.3)
# Requirement already satisfied: binaryornot==0.6.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 59)) (0.6.0)
# Requirement already satisfied: black==26.3.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 60)) (26.3.1)
# Requirement already satisfied: bleach==6.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 61)) (6.3.0)
# Requirement already satisfied: blinker==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 62)) (1.9.0)
# Requirement already satisfied: blis==1.3.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 63)) (1.3.3)
# Requirement already satisfied: boltons==25.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 64)) (25.0.0)
# Requirement already satisfied: boto3==1.37.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 65)) (1.37.3)
# Requirement already satisfied: botocore==1.37.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 66)) (1.37.3)
# Requirement already satisfied: Brotli==1.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 67)) (1.1.0)
# Requirement already satisfied: cached-property==1.5.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 68)) (1.5.2)
# Requirement already satisfied: cacheout==0.16.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 69)) (0.16.0)
# Requirement already satisfied: cachetools==5.5.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 70)) (5.5.2)
# Requirement already satisfied: catalogue==2.0.10 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 71)) (2.0.10)
# Requirement already satisfied: catboost==1.2.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 72)) (1.2.7)
# Requirement already satisfied: certifi==2026.2.25 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 73)) (2026.2.25)
# Requirement already satisfied: cffi==1.17.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 74)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.4.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 75)) (3.4.5)
# Requirement already satisfied: chronos-forecasting==2.2.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 76)) (2.2.2)
# Requirement already satisfied: click==8.3.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 77)) (8.3.1)
# Requirement already satisfied: cloudpathlib==0.23.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 78)) (0.23.0)
# Requirement already satisfied: cloudpickle==3.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 79)) (3.1.2)
# Requirement already satisfied: colorama==0.4.6 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 80)) (0.4.6)
# Requirement already satisfied: coloredlogs==15.0.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 81)) (15.0.1)
# Requirement already satisfied: colorful==0.5.8 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 82)) (0.5.8)
# Requirement already satisfied: colorlog==6.10.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 83)) (6.10.1)
# Requirement already satisfied: comm==0.2.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 84)) (0.2.3)
# Requirement already satisfied: conda==25.11.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 85)) (25.11.1)
# Requirement already satisfied: conda-libmamba-solver==25.11.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 86)) (25.11.0)
# Requirement already satisfied: conda-package-handling==2.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 87)) (2.4.0)
# Requirement already satisfied: conda_package_streaming==0.12.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 88)) (0.12.0)
# Requirement already satisfied: confection==0.1.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 89)) (0.1.5)
# Requirement already satisfied: contextlib2==21.6.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 90)) (21.6.0)
# Requirement already satisfied: contourpy==1.3.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 91)) (1.3.3)
# Requirement already satisfied: cookiecutter==2.7.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 92)) (2.7.1)
# Requirement already satisfied: coreforecast==0.0.16 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 93)) (0.0.16)
# Requirement already satisfied: croniter==1.4.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 94)) (1.4.1)
# Requirement already satisfied: cryptography==46.0.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 95)) (46.0.5)
# Requirement already satisfied: cycler==0.12.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 96)) (0.12.1)
# Requirement already satisfied: cymem==2.0.13 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 97)) (2.0.13)
# Requirement already satisfied: cytoolz==1.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 98)) (1.1.0)
# Requirement already satisfied: dash==2.18.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 99)) (2.18.1)
# Requirement already satisfied: dash-core-components==2.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 100)) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 101)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 102)) (5.0.0)
# Requirement already satisfied: dask==2026.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 103)) (2026.1.2)
# Requirement already satisfied: databricks-sdk==0.73.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 104)) (0.73.0)
# Requirement already satisfied: dataclasses==0.8 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 105)) (0.8)
# Requirement already satisfied: dataclasses-json==0.6.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 106)) (0.6.7)
# Requirement already satisfied: datasets==2.2.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 107)) (2.2.1)
# Requirement already satisfied: debugpy==1.8.20 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 108)) (1.8.20)
# Requirement already satisfied: decorator==5.2.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 109)) (5.2.1)
# Requirement already satisfied: deepmerge==2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 110)) (2.0)
# Requirement already satisfied: defusedxml==0.7.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 111)) (0.7.1)
# Requirement already satisfied: deltalake==1.3.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 112)) (1.3.2)
# Requirement already satisfied: Deprecated==1.3.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 113)) (1.3.1)
# Requirement already satisfied: dill==0.4.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 114)) (0.4.1)
# Requirement already satisfied: diskcache==5.6.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 115)) (5.6.3)
# Requirement already satisfied: distlib==0.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 116)) (0.4.0)
# Requirement already satisfied: distributed==2026.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 117)) (2026.1.2)
# Requirement already satisfied: distro==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 118)) (1.9.0)
# Requirement already satisfied: dnspython==2.8.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 119)) (2.8.0)
# Requirement already satisfied: docker==7.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 120)) (7.1.0)
# Requirement already satisfied: docstring_parser==0.17.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 121)) (0.17.0)
# Requirement already satisfied: docstring-to-markdown==0.17 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 122)) (0.17)
# Requirement already satisfied: donfig==0.8.1.post1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 123)) (0.8.1.post1)
# Requirement already satisfied: duckdb==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 124)) (1.5.0)
# Requirement already satisfied: einops==0.8.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 125)) (0.8.2)
# Requirement already satisfied: einx==0.4.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 126)) (0.4.2)
# Requirement already satisfied: email-validator==2.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 127)) (2.3.0)
# Requirement already satisfied: entrypoints==0.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 128)) (0.4)
# Requirement already satisfied: evaluate==0.4.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 129)) (0.4.1)
# Requirement already satisfied: exceptiongroup==1.3.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 130)) (1.3.1)
# Requirement already satisfied: executing==2.2.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 131)) (2.2.1)
# Requirement already satisfied: faiss==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 132)) (1.9.0)
# Requirement already satisfied: faiss-cpu==1.13.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 133)) (1.13.2)
# Requirement already satisfied: fastai==2.8.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 134)) (2.8.7)
# Requirement already satisfied: fastapi==0.128.8 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 135)) (0.128.8)
# Requirement already satisfied: fastapi-cli==0.0.23 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 136)) (0.0.23)
# Requirement already satisfied: fastcore==1.12.24 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 137)) (1.12.24)
# Requirement already satisfied: fastdownload==0.0.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 138)) (0.0.7)
# Requirement already satisfied: fastjsonschema==2.21.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 139)) (2.21.2)
# Requirement already satisfied: fastlite==0.2.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 140)) (0.2.3)
# Requirement already satisfied: fastprogress==1.1.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 141)) (1.1.3)
# Requirement already satisfied: fasttransform==0.0.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 142)) (0.0.2)
# Requirement already satisfied: filelock==3.25.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 143)) (3.25.2)
# Requirement already satisfied: flake8==7.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 144)) (7.1.2)
# Requirement already satisfied: Flask==3.0.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 145)) (3.0.3)
# Requirement already satisfied: flatbuffers==25.9.23 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 146)) (25.9.23)
# Requirement already satisfied: fonttools==4.62.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 147)) (4.62.0)
# Requirement already satisfied: fqdn==1.5.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 148)) (1.5.1)
# Requirement already satisfied: frozendict==2.4.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 149)) (2.4.7)
# Requirement already satisfied: frozenlist==1.7.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 150)) (1.7.0)
# Requirement already satisfied: fsspec==2024.12.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 151)) (2024.12.0)
# Requirement already satisfied: fugue==0.9.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 152)) (0.9.7)
# Requirement already satisfied: future==1.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 153)) (1.0.0)
# Requirement already satisfied: gast==0.7.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 154)) (0.7.0)
# Requirement already satisfied: gdown==5.2.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 155)) (5.2.1)
# Requirement already satisfied: git-remote-codecommit==1.16 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 156)) (1.16)
# Requirement already satisfied: gitdb==4.0.12 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 157)) (4.0.12)
# Requirement already satisfied: GitPython==3.1.46 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 158)) (3.1.46)
# Requirement already satisfied: gluonts==0.16.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 159)) (0.16.2)
# Requirement already satisfied: gmpy2==2.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 160)) (2.3.0)
# Requirement already satisfied: google-api-core==2.29.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 161)) (2.29.0)
# Requirement already satisfied: google-auth==2.49.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 162)) (2.49.1)
# Requirement already satisfied: google-cloud-bigquery==3.40.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 163)) (3.40.1)
# Requirement already satisfied: google-cloud-core==2.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 164)) (2.5.0)
# Requirement already satisfied: google-crc32c==1.8.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 165)) (1.8.0)
# Requirement already satisfied: google-pasta==0.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 166)) (0.2.0)
# Requirement already satisfied: google-resumable-media==2.8.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 167)) (2.8.0)
# Requirement already satisfied: googleapis-common-protos==1.73.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 168)) (1.73.0)
# Requirement already satisfied: graphene==3.4.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 169)) (3.4.3)
# Requirement already satisfied: graphql-core==3.2.8 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 170)) (3.2.8)
# Requirement already satisfied: graphql-relay==3.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 171)) (3.2.0)
# Requirement already satisfied: graphviz==0.21 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 172)) (0.21)
# Requirement already satisfied: greenlet==3.3.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 173)) (3.3.2)
# Requirement already satisfied: grpcio==1.67.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 174)) (1.67.1)
# Requirement already satisfied: grpcio-status==1.67.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 175)) (1.67.1)
# Requirement already satisfied: gssapi==1.10.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 176)) (1.10.1)
# Requirement already satisfied: gunicorn==23.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 177)) (23.0.0)
# Requirement already satisfied: h11==0.16.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 178)) (0.16.0)
# Requirement already satisfied: h2==4.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 179)) (4.3.0)
# Requirement already satisfied: h5py==3.15.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 180)) (3.15.1)
# Requirement already satisfied: hdijupyterutils==0.23.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 181)) (0.23.0)
# Requirement already satisfied: hf-xet==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 182)) (1.4.0)
# Requirement already satisfied: hpack==4.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 183)) (4.1.0)
# Requirement already satisfied: httpcore==1.0.9 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 184)) (1.0.9)
# Requirement already satisfied: httptools==0.7.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 185)) (0.7.1)
# Requirement already satisfied: httpx==0.28.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 186)) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 187)) (0.4.3)
# Requirement already satisfied: huggingface_hub==0.36.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 188)) (0.36.0)
# Requirement already satisfied: humanfriendly==10.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 189)) (10.0)
# Requirement already satisfied: hyperframe==6.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 190)) (6.1.0)
# Requirement already satisfied: hyperopt==0.2.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 191)) (0.2.7)
# Requirement already satisfied: idna==3.11 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 192)) (3.11)
# Requirement already satisfied: imagecodecs==2025.8.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 193)) (2025.8.2)
# Requirement already satisfied: imageio==2.37.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 194)) (2.37.0)
# Requirement already satisfied: importlib-metadata==6.10.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 195)) (6.10.0)
# Requirement already satisfied: importlib_resources==6.5.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 196)) (6.5.2)
# Requirement already satisfied: invoke==2.2.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 197)) (2.2.1)
# Requirement already satisfied: ipykernel==7.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 198)) (7.2.0)
# Requirement already satisfied: ipython==8.37.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 199)) (8.37.0)
# Requirement already satisfied: ipywidgets==8.1.8 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 200)) (8.1.8)
# Requirement already satisfied: isoduration==20.11.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 201)) (20.11.0)
# Requirement already satisfied: isort==8.0.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 202)) (8.0.1)
# Requirement already satisfied: itsdangerous==2.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 203)) (2.2.0)
# Requirement already satisfied: jedi==0.19.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 204)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 205)) (3.1.6)
# Requirement already satisfied: jiter==0.13.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 206)) (0.13.0)
# Requirement already satisfied: jmespath==1.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 207)) (1.1.0)
# Requirement already satisfied: joblib==1.5.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 208)) (1.5.3)
# Requirement already satisfied: json5==0.13.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 209)) (0.13.0)
# Requirement already satisfied: jsonpatch==1.33 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 210)) (1.33)
# Requirement already satisfied: jsonpath-ng==1.8.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 211)) (1.8.0)
# Requirement already satisfied: jsonpointer==3.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 212)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 213)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2025.9.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 214)) (2025.9.1)
# Requirement already satisfied: jupyter==1.1.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 215)) (1.1.1)
# Requirement already satisfied: jupyter-activity-monitor-extension==0.3.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 216)) (0.3.2)
# Requirement already satisfied: jupyter_ai==2.31.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 217)) (2.31.7)
# Requirement already satisfied: jupyter_ai_magics==2.31.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 218)) (2.31.7)
# Requirement already satisfied: jupyter_client==8.8.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 219)) (8.8.0)
# Requirement already satisfied: jupyter-collaboration==3.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 220)) (3.1.2)
# Requirement already satisfied: jupyter-collaboration-ui==1.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 221)) (1.1.2)
# Requirement already satisfied: jupyter-console==6.6.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 222)) (6.6.3)
# Requirement already satisfied: jupyter_core==5.9.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 223)) (5.9.1)
# Requirement already satisfied: jupyter-dash==0.4.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 224)) (0.4.2)
# Requirement already satisfied: jupyter-docprovider==1.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 225)) (1.1.2)
# Requirement already satisfied: jupyter-events==0.12.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 226)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 227)) (2.3.0)
# Requirement already satisfied: jupyter_scheduler==2.11.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 228)) (2.11.0)
# Requirement already satisfied: jupyter_server==2.17.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 229)) (2.17.0)
# Requirement already satisfied: jupyter_server_fileid==0.9.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 230)) (0.9.2)
# Requirement already satisfied: jupyter_server_proxy==4.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 231)) (4.4.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 232)) (0.5.4)
# Requirement already satisfied: jupyter-server-ydoc==1.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 233)) (1.1.2)
# Requirement already satisfied: jupyter-ydoc==3.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 234)) (3.4.0)
# Requirement already satisfied: jupyterlab==4.4.10 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 235)) (4.4.10)
# Requirement already satisfied: jupyterlab_git==0.51.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 236)) (0.51.4)
# Requirement already satisfied: jupyterlab-lsp==5.0.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 237)) (5.0.3)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 238)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.28.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 239)) (2.28.0)
# Requirement already satisfied: jupyterlab_widgets==3.0.16 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 240)) (3.0.16)
# Requirement already satisfied: kagglehub==1.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 241)) (1.0.0)
# Requirement already satisfied: kagglesdk==0.1.16 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 242)) (0.1.16)
# Requirement already satisfied: keras==3.12.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 243)) (3.12.0)
# Requirement already satisfied: kiwisolver==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 244)) (1.5.0)
# Requirement already satisfied: krb5==0.5.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 245)) (0.5.1)
# Requirement already satisfied: langchain==0.3.27 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 246)) (0.3.27)
# Requirement already satisfied: langchain-aws==0.2.18 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 247)) (0.2.18)
# Requirement already satisfied: langchain-community==0.3.31 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 248)) (0.3.31)
# Requirement already satisfied: langchain-core==0.3.81 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 249)) (0.3.81)
# Requirement already satisfied: langchain-openai==0.3.35 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 250)) (0.3.35)
# Requirement already satisfied: langchain-text-splitters==0.3.11 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 251)) (0.3.11)
# Requirement already satisfied: langsmith==0.7.17 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 252)) (0.7.17)
# Requirement already satisfied: lazy-loader==0.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 253)) (0.5)
# Requirement already satisfied: libmambapy==2.3.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 254)) (2.3.2)
# Requirement already satisfied: lightgbm==4.6.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 255)) (4.6.0)
# Requirement already satisfied: lightning==2.5.6 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 256)) (2.5.6)
# Requirement already satisfied: lightning-utilities==0.15.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 257)) (0.15.3)
# Requirement already satisfied: llvmlite==0.46.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 258)) (0.46.0)
# Requirement already satisfied: locket==1.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 259)) (1.0.0)
# Requirement already satisfied: loguru==0.7.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 260)) (0.7.3)
# Requirement already satisfied: lxml==5.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 261)) (5.4.0)
# Requirement already satisfied: Mako==1.3.10 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 262)) (1.3.10)
# Requirement already satisfied: Markdown==3.10.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 263)) (3.10.2)
# Requirement already satisfied: markdown-it-py==4.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 264)) (4.0.0)
# Requirement already satisfied: MarkupSafe==3.0.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 265)) (3.0.3)
# Requirement already satisfied: marshmallow==3.26.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 266)) (3.26.1)
# Requirement already satisfied: matplotlib==3.10.8 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 267)) (3.10.8)
# Requirement already satisfied: matplotlib-inline==0.2.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 268)) (0.2.1)
# Requirement already satisfied: mccabe==0.7.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 269)) (0.7.0)
# Requirement already satisfied: mcp==1.25.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 270)) (1.25.0)
# Requirement already satisfied: mdurl==0.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 271)) (0.1.2)
# Requirement already satisfied: menuinst==2.4.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 272)) (2.4.2)
# Requirement already satisfied: mistune==3.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 273)) (3.2.0)
# Requirement already satisfied: ml-dtypes==0.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 274)) (0.4.0)
# Requirement already satisfied: mlflow==2.22.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 275)) (2.22.0)
# Requirement already satisfied: mlflow-skinny==2.22.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 276)) (2.22.0)
# Requirement already satisfied: mlforecast==0.14.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 277)) (0.14.0)
# Requirement already satisfied: mmh3==5.2.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 278)) (5.2.1)
# Requirement already satisfied: mock==4.0.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 279)) (4.0.3)
# Requirement already satisfied: model-index==0.1.11 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 280)) (0.1.11)
# Requirement already satisfied: mpmath==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 281)) (1.4.0)
# Requirement already satisfied: msgpack==1.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 282)) (1.1.2)
# Requirement already satisfied: multidict==6.7.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 283)) (6.7.1)
# Requirement already satisfied: multiprocess==0.70.19 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 284)) (0.70.19)
# Requirement already satisfied: munkres==1.1.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 285)) (1.1.4)
# Requirement already satisfied: murmurhash==1.0.15 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 286)) (1.0.15)
# Requirement already satisfied: mypy_extensions==1.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 287)) (1.1.0)
# Requirement already satisfied: namex==0.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 288)) (0.1.0)
# Requirement already satisfied: narwhals==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 289)) (2.18.0)
# Requirement already satisfied: nbclient==0.10.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 290)) (0.10.4)
# Requirement already satisfied: nbconvert==7.17.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 291)) (7.17.0)
# Requirement already satisfied: nbdime==4.0.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 292)) (4.0.4)
# Requirement already satisfied: nbformat==5.10.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 293)) (5.10.4)
# Requirement already satisfied: nest_asyncio==1.6.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 294)) (1.6.0)
# Requirement already satisfied: networkx==3.6.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 295)) (3.6.1)
# Requirement already satisfied: nlpaug==1.1.11 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 296)) (1.1.11)
# Requirement already satisfied: nltk==3.9.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 297)) (3.9.3)
# Requirement already satisfied: nose==1.3.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 298)) (1.3.7)
# Requirement already satisfied: notebook==7.4.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 299)) (7.4.7)
# Requirement already satisfied: notebook_shim==0.2.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 300)) (0.2.4)
# Requirement already satisfied: numba==0.64.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 301)) (0.64.0)
# Requirement already satisfied: numcodecs==0.16.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 302)) (0.16.5)
# Requirement already satisfied: numpy==1.26.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 303)) (1.26.4)
# Requirement already satisfied: nvidia-ml-py3==7.352.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 304)) (7.352.0)
# Requirement already satisfied: oauthlib==3.3.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 305)) (3.3.1)
# Requirement already satisfied: omegaconf==2.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 306)) (2.3.0)
# Requirement already satisfied: onnxruntime==1.24.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 307)) (1.24.2)
# Requirement already satisfied: openai==1.109.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 308)) (1.109.1)
# Requirement already satisfied: opencensus==0.11.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 309)) (0.11.3)
# Requirement already satisfied: opencensus-context==0.1.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 310)) (0.1.3)
# Requirement already satisfied: openmim==0.3.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 311)) (0.3.7)
# Requirement already satisfied: opentelemetry-api==1.40.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 312)) (1.40.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.61b0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 313)) (0.61b0)
# Requirement already satisfied: opentelemetry-instrumentation-threading==0.61b0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 314)) (0.61b0)
# Requirement already satisfied: opentelemetry-sdk==1.40.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 315)) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 316)) (0.61b0)
# Requirement already satisfied: opt_einsum==3.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 317)) (3.4.0)
# Requirement already satisfied: optree==0.19.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 318)) (0.19.0)
# Requirement already satisfied: optuna==4.7.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 319)) (4.7.0)
# Requirement already satisfied: ordered-set==4.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 320)) (4.1.0)
# Requirement already satisfied: orjson==3.11.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 321)) (3.11.7)
# Requirement already satisfied: overrides==7.7.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 322)) (7.7.0)
# Requirement already satisfied: packaging==24.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 323)) (24.2)
# Requirement already satisfied: pandas==2.3.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 324)) (2.3.3)
# Requirement already satisfied: pandocfilters==1.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 325)) (1.5.0)
# Requirement already satisfied: papermill==2.7.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 326)) (2.7.0)
# Requirement already satisfied: paramiko==4.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 327)) (4.0.0)
# Requirement already satisfied: parso==0.8.6 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 328)) (0.8.6)
# Requirement already satisfied: partd==1.4.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 329)) (1.4.2)
# ...
# Requirement already satisfied: simpervisor==1.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 462)) (1.0.0)
# Requirement already satisfied: six==1.17.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 463)) (1.17.0)
# Requirement already satisfied: slack_bolt==1.27.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 464)) (1.27.0)
# Requirement already satisfied: slack_sdk==3.41.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 465)) (3.41.0)
# Requirement already satisfied: smart_open==7.5.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 466)) (7.5.1)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 467)) (1.0.1)
# Requirement already satisfied: smmap==5.0.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 468)) (5.0.2)
# Requirement already satisfied: sniffio==1.3.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 469)) (1.3.1)
# Requirement already satisfied: snowballstemmer==3.0.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 470)) (3.0.1)
# Requirement already satisfied: snowflake-connector-python==3.17.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 471)) (3.17.4)
# Requirement already satisfied: snowflake-sqlalchemy==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 472)) (1.9.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 473)) (2.4.0)
# Requirement already satisfied: soupsieve==2.8.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 474)) (2.8.3)
# Requirement already satisfied: spacy==3.8.11 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 475)) (3.8.11)
# Requirement already satisfied: spacy-legacy==3.0.12 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 476)) (3.0.12)
# Requirement already satisfied: spacy-loggers==1.0.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 477)) (1.0.5)
# Requirement already satisfied: sparkmagic==0.22.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 478)) (0.22.0)
# Requirement already satisfied: SQLAlchemy==2.0.48 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 479)) (2.0.48)
# Requirement already satisfied: sqlalchemy-bigquery==1.16.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 480)) (1.16.0)
# Requirement already satisfied: sqlite-anyio==0.2.8 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 481)) (0.2.8)
# Requirement already satisfied: sqlparse==0.5.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 482)) (0.5.0)
# Requirement already satisfied: srsly==2.5.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 483)) (2.5.2)
# Requirement already satisfied: sse-starlette==3.3.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 484)) (3.3.2)
# Requirement already satisfied: stack_data==0.6.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 485)) (0.6.3)
# Requirement already satisfied: starlette==0.52.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 486)) (0.52.1)
# Requirement already satisfied: statsforecast==2.0.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 487)) (2.0.1)
# Requirement already satisfied: statsmodels==0.14.6 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 488)) (0.14.6)
# Requirement already satisfied: stevedore==5.4.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 489)) (5.4.1)
# Requirement already satisfied: strands-agents==0.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 490)) (0.3.0)
# Requirement already satisfied: strands-agents-mcp-server==0.1.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 491)) (0.1.2)
# Requirement already satisfied: strands-agents-tools==0.1.9 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 492)) (0.1.9)
# Requirement already satisfied: strictyaml==1.7.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 493)) (1.7.3)
# Requirement already satisfied: supervisor==4.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 494)) (4.3.0)
# Requirement already satisfied: sympy==1.14.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 495)) (1.14.0)
# Requirement already satisfied: tabulate==0.10.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 496)) (0.10.0)
# Requirement already satisfied: tblib==3.2.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 497)) (3.2.2)
# Requirement already satisfied: tenacity==9.1.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 498)) (9.1.4)
# Requirement already satisfied: tensorboard==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 499)) (2.18.0)
# Requirement already satisfied: tensorboard_data_server==0.7.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 500)) (0.7.0)
# Requirement already satisfied: tensorboardX==2.6.2.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 501)) (2.6.2.2)
# Requirement already satisfied: tensorflow==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 502)) (2.18.0)
# Requirement already satisfied: tensorflow_estimator==2.15.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 503)) (2.15.0)
# Requirement already satisfied: termcolor==3.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 504)) (3.3.0)
# Requirement already satisfied: terminado==0.18.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 505)) (0.18.1)
# Requirement already satisfied: text-unidecode==1.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 506)) (1.3)
# Requirement already satisfied: tf_keras==2.18.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 507)) (2.18.0)
# Requirement already satisfied: thinc==8.3.10 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 508)) (8.3.10)
# Requirement already satisfied: threadpoolctl==3.6.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 509)) (3.6.0)
# Requirement already satisfied: thrift==0.22.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 510)) (0.22.0)
# Requirement already satisfied: thrift_sasl==0.4.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 511)) (0.4.3)
# Requirement already satisfied: tifffile==2025.12.12 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 512)) (2025.12.12)
# Requirement already satisfied: tiktoken==0.12.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 513)) (0.12.0)
# Requirement already satisfied: timm==1.0.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 514)) (1.0.3)
# Requirement already satisfied: tinycss2==1.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 515)) (1.4.0)
# Requirement already satisfied: tokenizers==0.22.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 516)) (0.22.2)
# Requirement already satisfied: tomli==2.4.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 517)) (2.4.0)
# Requirement already satisfied: tomlkit==0.14.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 518)) (0.14.0)
# Requirement already satisfied: toolz==0.12.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 519)) (0.12.1)
# Requirement already satisfied: torch==2.6.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 520)) (2.6.0)
# Requirement already satisfied: torchmetrics==1.7.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 521)) (1.7.4)
# Requirement already satisfied: torchvision==0.21.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 522)) (0.21.0)
# Requirement already satisfied: torchvision-extra-decoders==0.0.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 523)) (0.0.2)
# Requirement already satisfied: tornado==6.5.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 524)) (6.5.4)
# Requirement already satisfied: tqdm==4.67.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 525)) (4.67.3)
# Requirement already satisfied: traitlets==5.14.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 526)) (5.14.3)
# Requirement already satisfied: transformers==4.57.6 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 527)) (4.57.6)
# Requirement already satisfied: triad==1.0.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 528)) (1.0.2)
# Requirement already satisfied: truststore==0.10.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 529)) (0.10.4)
# Requirement already satisfied: typer==0.24.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 530)) (0.24.0)
# Requirement already satisfied: typer-slim==0.24.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 531)) (0.24.0)
# Requirement already satisfied: typing_extensions==4.15.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 532)) (4.15.0)
# Requirement already satisfied: typing_inspect==0.9.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 533)) (0.9.0)
# Requirement already satisfied: typing-inspection==0.4.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 534)) (0.4.2)
# Requirement already satisfied: typing_utils==0.1.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 535)) (0.1.0)
# Requirement already satisfied: tzdata==2025.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 536)) (2025.3)
# Requirement already satisfied: ujson==5.12.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 537)) (5.12.0)
# Requirement already satisfied: unicodedata2==17.0.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 538)) (17.0.1)
# Requirement already satisfied: uri-template==1.3.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 539)) (1.3.0)
# Requirement already satisfied: urllib3==1.26.20 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 540)) (1.26.20)
# Requirement already satisfied: utilsforecast==0.2.11 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 541)) (0.2.11)
# Requirement already satisfied: uuid_utils==0.14.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 542)) (0.14.1)
# Requirement already satisfied: uvicorn==0.40.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 543)) (0.40.0)
# Requirement already satisfied: uvloop==0.22.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 544)) (0.22.1)
# Requirement already satisfied: virtualenv==21.2.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 545)) (21.2.0)
# Requirement already satisfied: wasabi==1.1.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 546)) (1.1.3)
# Requirement already satisfied: watchdog==6.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 547)) (6.0.0)
# Requirement already satisfied: watchfiles==1.1.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 548)) (1.1.1)
# Requirement already satisfied: wcwidth==0.6.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 549)) (0.6.0)
# Requirement already satisfied: weasel==0.4.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 550)) (0.4.3)
# Requirement already satisfied: webcolors==25.10.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 551)) (25.10.0)
# Requirement already satisfied: webencodings==0.5.1 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 552)) (0.5.1)
# Requirement already satisfied: websocket-client==1.9.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 553)) (1.9.0)
# Requirement already satisfied: websockets==16.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 554)) (16.0)
# Requirement already satisfied: Werkzeug==3.0.6 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 555)) (3.0.6)
# Requirement already satisfied: whatthepatch==1.0.7 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 556)) (1.0.7)
# Requirement already satisfied: wheel==0.46.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 557)) (0.46.3)
# Requirement already satisfied: widgetsnbextension==4.0.15 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 558)) (4.0.15)
# Requirement already satisfied: window_ops==0.0.15 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 559)) (0.0.15)
# Requirement already satisfied: wrapt==1.17.3 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 560)) (1.17.3)
# Requirement already satisfied: xgboost==2.1.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 561)) (2.1.4)
# Requirement already satisfied: xxhash==3.6.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 562)) (3.6.0)
# Requirement already satisfied: y-py==0.6.2 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 563)) (0.6.2)
# Requirement already satisfied: yapf==0.43.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 564)) (0.43.0)
# Requirement already satisfied: yarl==1.23.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 565)) (1.23.0)
# Requirement already satisfied: ypy-websocket==0.12.4 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 566)) (0.12.4)
# Requirement already satisfied: zarr==3.1.5 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 567)) (3.1.5)
# Requirement already satisfied: zict==3.0.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 568)) (3.0.0)
# Requirement already satisfied: zipp==3.23.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 569)) (3.23.0)
# Requirement already satisfied: zstandard==0.25.0 in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 570)) (0.25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
from botocore.client import ClientError
import sagemaker

session = boto3.session.Session()
region = session.region_name
sagemaker_session = sagemaker.Session()
default_bucket = sagemaker_session.default_bucket()

s3 = boto3.Session().client(service_name="s3", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
print(f"Default bucket: {default_bucket}")
# Out:
# Default bucket: sagemaker-us-east-1-298748835671

# %%
s3_project_root = "floorplan-generator"

# %%
# %store default_bucket s3_project_root
# Out:
# Stored 'default_bucket' (str)
# Stored 's3_project_root' (str)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# default_bucket              -> 'sagemaker-us-east-1-298748835671'
# s3_project_root             -> 'floorplan-generator'
