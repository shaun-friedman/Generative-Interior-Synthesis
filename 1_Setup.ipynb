# %%
# %pip install -r ./src/requirements.txt
# Out:
# Collecting zarr (from -r ./src/requirements.txt (line 1))
#   Using cached zarr-3.1.6-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: s3fs in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 2)) (2024.6.1)
# Requirement already satisfied: kagglehub in /opt/conda/lib/python3.12/site-packages (from -r ./src/requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: donfig>=0.8 in /opt/conda/lib/python3.12/site-packages (from zarr->-r ./src/requirements.txt (line 1)) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /opt/conda/lib/python3.12/site-packages (from zarr->-r ./src/requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /opt/conda/lib/python3.12/site-packages (from zarr->-r ./src/requirements.txt (line 1)) (0.16.5)
# Collecting numpy>=2.0 (from zarr->-r ./src/requirements.txt (line 1))
#   Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.12/site-packages (from zarr->-r ./src/requirements.txt (line 1)) (24.2)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/conda/lib/python3.12/site-packages (from zarr->-r ./src/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.12/site-packages (from s3fs->-r ./src/requirements.txt (line 2)) (2.22.0)
# Requirement already satisfied: fsspec==2024.6.1.* in /opt/conda/lib/python3.12/site-packages (from s3fs->-r ./src/requirements.txt (line 2)) (2024.6.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.12/site-packages (from s3fs->-r ./src/requirements.txt (line 2)) (3.13.3)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r ./src/requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: botocore<1.37.4,>=1.37.2 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r ./src/requirements.txt (line 2)) (1.37.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r ./src/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r ./src/requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r ./src/requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r ./src/requirements.txt (line 2)) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r ./src/requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r ./src/requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r ./src/requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r ./src/requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r ./src/requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r ./src/requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<1.37.4,>=1.37.2->aiobotocore<3.0.0,>=2.5.4->s3fs->-r ./src/requirements.txt (line 2)) (1.26.20)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs->-r ./src/requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r ./src/requirements.txt (line 2)) (3.11)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /opt/conda/lib/python3.12/site-packages (from kagglehub->-r ./src/requirements.txt (line 3)) (0.1.16)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.12/site-packages (from kagglehub->-r ./src/requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from kagglehub->-r ./src/requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from kagglehub->-r ./src/requirements.txt (line 3)) (4.67.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.12/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub->-r ./src/requirements.txt (line 3)) (5.28.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->kagglehub->-r ./src/requirements.txt (line 3)) (3.4.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->kagglehub->-r ./src/requirements.txt (line 3)) (2026.2.25)
# Using cached zarr-3.1.6-py3-none-any.whl (295 kB)
# Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Installing collected packages: numpy, zarr
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:━━━━━━━━━━━━━━━━━━ 0/2 [numpy]
#       Successfully uninstalled numpy-1.26.4━ 0/2 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [zarr]1/2 [zarr]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.5.0 requires nvidia-ml-py3<8.0,>=7.352.0, which is not installed.
# autogluon-timeseries 1.5.0 requires chronos-forecasting<2.4,>=2.2.2, which is not installed.
# autogluon-timeseries 1.5.0 requires einops<1,>=0.7, which is not installed.
# autogluon-timeseries 1.5.0 requires peft<0.18,>=0.13.0, which is not installed.
# amazon-sagemaker-jupyter-ai-q-developer 1.2.9 requires numpy<=2.0.1, but you have numpy 2.4.4 which is incompatible.
# amazon-sagemaker-sql-magic 0.1.4 requires numpy<2, but you have numpy 2.4.4 which is incompatible.
# autogluon-common 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.4 which is incompatible.
# autogluon-core 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.4 which is incompatible.
# autogluon-features 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.4 which is incompatible.
# autogluon-multimodal 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.4 which is incompatible.
# autogluon-tabular 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.4 which is incompatible.
# autogluon-timeseries 1.5.0 requires numpy<2.4.0,>=1.25.0, but you have numpy 2.4.4 which is incompatible.
# catboost 1.2.7 requires numpy<2.0,>=1.16.0, but you have numpy 2.4.4 which is incompatible.
# gluonts 0.16.2 requires numpy<2.2,>=1.16, but you have numpy 2.4.4 which is incompatible.
# langchain-aws 0.2.19 requires boto3>=1.37.24, but you have boto3 1.37.3 which is incompatible.
# sagemaker 2.245.0 requires numpy==1.26.4, but you have numpy 2.4.4 which is incompatible.
# sagemaker-studio 1.1.8 requires numpy<2.3.0,>=1.26.4, but you have numpy 2.4.4 which is incompatible.
# sagemaker-studio 1.1.8 requires pandas<3.0.0,>=2.3.2, but you have pandas 2.2.0 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.0 which is incompatible.
# pandas 2.2.0 requires numpy<2,>=1.26.0; python_version >= "3.12", but you have numpy 2.4.4 which is incompatible.
# Successfully installed numpy-2.4.4 zarr-3.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
from botocore.client import ClientError
import sagemaker

session = boto3.session.Session()
region = session.region_name
sagemaker_session = sagemaker.Session()
default_bucket = sagemaker_session.default_bucket()

s3 = boto3.Session().client(service_name="s3", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
print(f"Default bucket: {default_bucket}")
# Out:
# Default bucket: sagemaker-us-east-1-298748835671

# %%
s3_project_root = "floorplan-generator"

# %%
# %store default_bucket s3_project_root
# Out:
# Stored 'default_bucket' (str)
# Stored 's3_project_root' (str)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# default_bucket                -> 'sagemaker-us-east-1-298748835671'
# s3_project_prefix             -> 's3://sagemaker-us-east-1-298748835671/floorplan-g
# s3_project_root               -> 'floorplan-generator'
