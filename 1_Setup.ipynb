# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: zarr in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: s3fs in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2024.12.0)
# Requirement already satisfied: kagglehub in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.0.0)
# Collecting opencv-python (from -r requirements.txt (line 4))
#   Using cached opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: donfig>=0.8 in /opt/conda/lib/python3.12/site-packages (from zarr->-r requirements.txt (line 1)) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /opt/conda/lib/python3.12/site-packages (from zarr->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /opt/conda/lib/python3.12/site-packages (from zarr->-r requirements.txt (line 1)) (0.16.5)
# Requirement already satisfied: numpy>=2.0 in /opt/conda/lib/python3.12/site-packages (from zarr->-r requirements.txt (line 1)) (2.4.4)
# Requirement already satisfied: packaging>=22.0 in /opt/conda/lib/python3.12/site-packages (from zarr->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: typing-extensions>=4.12 in /opt/conda/lib/python3.12/site-packages (from zarr->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.12/site-packages (from s3fs->-r requirements.txt (line 2)) (2.22.0)
# Requirement already satisfied: fsspec==2024.12.0.* in /opt/conda/lib/python3.12/site-packages (from s3fs->-r requirements.txt (line 2)) (2024.12.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.12/site-packages (from s3fs->-r requirements.txt (line 2)) (3.13.3)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: botocore<1.37.4,>=1.37.2 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 2)) (1.37.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 2)) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<1.37.4,>=1.37.2->aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 2)) (1.26.20)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /opt/conda/lib/python3.12/site-packages (from kagglehub->-r requirements.txt (line 3)) (0.1.16)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.12/site-packages (from kagglehub->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from kagglehub->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from kagglehub->-r requirements.txt (line 3)) (4.67.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.12/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub->-r requirements.txt (line 3)) (5.28.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->kagglehub->-r requirements.txt (line 3)) (3.4.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->kagglehub->-r requirements.txt (line 3)) (2026.2.25)
# Using cached opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
from botocore.client import ClientError
import sagemaker

session = boto3.session.Session()
region = session.region_name
sagemaker_session = sagemaker.Session()
default_bucket = sagemaker_session.default_bucket()

s3 = boto3.Session().client(service_name="s3", region_name=region)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
print(f"Default bucket: {default_bucket}")
# Out:
# Default bucket: sagemaker-us-east-1-298748835671

# %%
s3_project_root = "floorplan-generator"

# %%
# %store default_bucket s3_project_root
# Out:
# Stored 'default_bucket' (str)
# Stored 's3_project_root' (str)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# default_bucket                -> 'sagemaker-us-east-1-298748835671'
# s3_project_prefix             -> 's3://sagemaker-us-east-1-298748835671/floorplan-g
# s3_project_root               -> 'floorplan-generator'
